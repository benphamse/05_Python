# %%
s = set(map(str, input().lower().split()))
t = set(map(str, input().lower().split()))

ans = []
for x in s : 
    if x not in t : 
        ans.append(x)
ans.sort()
for x in ans : 
    print(x, end = ' ')
