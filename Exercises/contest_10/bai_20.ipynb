# %%
s = input()
def check() : 
    d = 0
    tmp = 'python'
    for x in s :
        if tmp[d] == x : 
            if d == 5 : return True
            d += 1
    return False
if __name__ == '__main__' : 
    print('YES' if check() else 'NO')
