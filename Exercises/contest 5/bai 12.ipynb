# %%
n = int(input())
a = list(map(int, input().split()))

minval, maxval = 10 ** 7, -10 ** 7
idx, idx2 = 0, 0
for i in range(n):
    if a[i] <= minval :
        minval = a[i]
        idx = i
    if a[i] > maxval :
        maxval = a[i]
        idx2 = i
print(idx, idx2)
