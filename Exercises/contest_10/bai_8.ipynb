# %%
s = input()
def check() : 
    cnt = [0] * 26
    for x in s : 
        cnt[ord(x.lower()) - ord('a')] = 1
    ans = 0
    for x in range(26) : 
        if(cnt[x] == 1) : ans += 1
    return ans == 26
if __name__ == '__main__' : 
    print(('YES' if check() else "NO"))
