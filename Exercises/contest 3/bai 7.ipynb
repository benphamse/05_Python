# %%
from math import *

def gcd(a, b) :
    while b :
        a, b = b, a % b
    return a

def lcm(a, b) :
    return a * gcd(a, b) // b

if __name__  == '__main__' :
    a, b = map(int, input().split())
    for i in range(a, b + 1) :
        for j in range(i + 1, b + 1) :
            if (gcd(i, j) == 1) :
                print('(', i, ',', j, ')', sep = '')
# Out:
# 5 46
# (5,6)
# (5,7)
# (5,8)
# (5,9)
# (5,11)
# (5,12)
# (5,13)
# (5,14)
# (5,16)
# (5,17)
# (5,18)
# (5,19)
# (5,21)
# (5,22)
# (5,23)
# (5,24)
# (5,26)
# (5,27)
# (5,28)
# (5,29)
# (5,31)
# (5,32)
# (5,33)
# (5,34)
# (5,36)
# (5,37)
# (5,38)
# (5,39)
# (5,41)
# (5,42)
# (5,43)
# (5,44)
# (5,46)
# (6,7)
# (6,11)
# (6,13)
# (6,17)
# (6,19)
# (6,23)
# (6,25)
# (6,29)
# (6,31)
# (6,35)
# (6,37)
# (6,41)
# (6,43)
# (7,8)
# (7,9)
# (7,10)
# (7,11)
# (7,12)
# (7,13)
# (7,15)
# (7,16)
# (7,17)
# (7,18)
# (7,19)
# (7,20)
# (7,22)
# (7,23)
# (7,24)
# (7,25)
# (7,26)
# (7,27)
# (7,29)
# (7,30)
# (7,31)
# (7,32)
# (7,33)
# (7,34)
# (7,36)
# (7,37)
# (7,38)
# (7,39)
# (7,40)
# (7,41)
# (7,43)
# (7,44)
# (7,45)
# (7,46)
# (8,9)
# (8,11)
# (8,13)
# (8,15)
# (8,17)
# (8,19)
# (8,21)
# (8,23)
# (8,25)
# (8,27)
# (8,29)
# (8,31)
# (8,33)
# (8,35)
# (8,37)
# (8,39)
# (8,41)
# (8,43)
# (8,45)
# (9,10)
# (9,11)
# (9,13)
# (9,14)
# (9,16)
# (9,17)
# (9,19)
# (9,20)
# (9,22)
# (9,23)
# (9,25)
# (9,26)
# ...
