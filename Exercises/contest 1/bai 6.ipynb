# %%
x = int(input())

if x % 2 == 0 : 
    print("YES")
else :
    print("NO")

if x % 3 == 0 and x % 5 == 0 : 
    print("YES")
else : 
    print("NO")

if x % 3 == 0 and x % 7 != 0 : 
    print("YES")
else : 
    print("NO")

if x % 3 == 0 or x % 7 == 0 : 
    print("YES")
else : 
    print("NO")

if x > 30 and x < 50 :
    print("YES")
else : 
    print("NO")

if x >= 30 and (x % 2 == 0 or x % 3 == 0 or x % 5 == 0) : 
    print("YES")
else : 
    print("NO")

k = x % 10

if x >= 10 and x <= 99 and (k == 2 or k == 3 or k == 5 or k == 7): 
    print("YES")
else : 
    print("NO")

if x <= 100 and x % 23 == 0 : 
    print("YES")
else : 
    print("NO")

if x < 10 or x > 20 : 
    print("YES")
else : 
    print("NO")

if k % 3 == 0 :
    print("YES")
else : 
    print("NO")
# Out:
# 100
# YES
# NO
# NO
# NO
# NO
# YES
# NO
# NO
# YES
# YES
