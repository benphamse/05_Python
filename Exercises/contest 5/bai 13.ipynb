# %%
mod = (int)(1e9 + 7)
n = int(input())
a = list(map(int, input().split()))
sum , mul = 0, 1
for i in a :
    sum += i
    sum %= mod
    mul *= i
    mul %= mod
print(sum % mod, mul % mod, sep = '\n')
