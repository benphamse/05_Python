# %%
n, a, b = map (int, input().split())

# print(13 // 2)

if(a <= b / 2) : 
    print (n * a)
else : 
    if n % 2 == 0 : 
        print (n // 2 * b)
    else : 
        print((n - 1) // 2 * b + a)
# Out:
# 13 4 2
# 6
# 16
