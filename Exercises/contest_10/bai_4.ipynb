# %%
s = input()
cnt = [0] * 256
for x in s : 
    cnt[ord(x)] += 1
min_val, min_fre, max_val, max_fre = 0, 10 ** 18, 0, -10 ** 18
for x in range(256) : 
    if(cnt[x] != 0) : 
        if min_fre >= cnt[x] : 
            min_fre = cnt[x]
            min_val = chr(x)
        if max_fre <= cnt[x] : 
            max_fre = cnt[x]
            max_val = chr(x)
print(max_val, max_fre)
print(min_val, min_fre)
