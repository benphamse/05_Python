# %%
def lp(n) :
    while n :
        r = n % 10
        if (r != 0 and r != 6 and r != 8) : return False
        n //= 10
    return True

if __name__ == '__main__' :
    n = int(input())
    print(1 if lp(n) else 0)
# Out:
# 60806
# 1
