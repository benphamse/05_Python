# %%
n = int(input())
a = set(map(int, input().split()))
q = int(input())
for i in range(q) :
    k = int(input())
    if k in a : 
        print('YES')
    else : 
        print('NO')
# Out:
# 4
# 1 2 3 4
# 3
