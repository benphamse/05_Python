# %%
n = int(input())
a = list(map(int, input().split()))

a.sort()

idx, ans ,cnt = 1, a[0], 1

for i in range(n - 1) :
    if(a[i] == a[i + 1]) :
        cnt += 1
    else : 
        cnt = 1
    if(cnt > idx) :
        idx = cnt
        ans = a[i]
print(ans, idx)
# Out:
# 1
# 1
# 0 1
