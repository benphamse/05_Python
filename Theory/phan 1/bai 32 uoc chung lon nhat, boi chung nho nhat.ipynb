# %%
# ucln, bcnn
# thuat toan euclid

def gcd (a, b) :
    while b : 
#         doi a, b => b, a % b 
        a, b, = b, a % b 
    return a

def lcm (a, b) :
    return a // gcd(a, b) * b

if __name__ == '__main__' :
    a, b, c = map(int, input().split())
    print(gcd(gcd(a,b), c), lcm(lcm(a, b), c))
# Out:
# 10 15 20
# 5 60
