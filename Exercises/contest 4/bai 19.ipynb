# %%
def check(n) :
    if n <= 9 :
        return n % 2 == 0
    if n % 10 % 2 == 1 : 
        return False
    return check(n // 10)

if __name__ == '__main__' :
    n = int(input())
    print("YES" if check(n) else "NO")
# Out:
# 2280820
# YES
