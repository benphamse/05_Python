# %%
n, m = map(int, input().split())
a = list(map(int, input().split()))
b = list(map(int, input().split()))
d = dict({})
for x in a : 
    d[x] = 1
for x in b : 
    if x in d: 
        d[x] = 2
    else : 
        d[x] = 1
k = []
for x in d : 
    k.append(x)    
k.sort()
for x in k : 
    print(x, end = ' ')
print()
z = []
for x in d : 
    if (d[x] == 2) :
        z.append(x)
for x in z : 
    print(x, end = ' ')
