# %%
from math import *

def nt(n) :
    if n < 2 : return False
    for i in range(2, isqrt(n) + 1) :
        if n % i == 0 : 
            return False
    return True

if __name__ == '__main__' :
    a = [1, 2, 3, 4]
    b = list(filter(lambda x : x % 2 == 1, a))
    print(a, b, sep = '\n')
# Out:
# [1, 2, 3, 4]
# [1, 3]
