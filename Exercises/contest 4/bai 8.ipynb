# %%
def gcd(a, b) :
    return a if b == 0 else gcd(b, a % b)

def lcm(a, b) :
    return a // gcd(a, b) * b

if __name__ == '__main__' :
    a, b = map(int, input().split())
    print(gcd(a, b), lcm(a, b))
# Out:
# 10 20
# 10 20
