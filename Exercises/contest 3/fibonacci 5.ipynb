# %%
def fibo(n) :
    if n == 0 or n == 1 : return True
    fn1, fn2 = 1, 1
    for i in range(2, 93) :
        fn = fn1 + fn2
        if fn == n : return True
        fn1, fn2 = fn, fn1
    return False

if __name__ == '__main__' :
    n = int(input())
    for i in range(n) :
        k = int(input())
        print("YES" if fibo(k) else "NO")
# Out:
# 5
# 89
# YES
# 754
# NO
# 1
# NO
# 0
# NO
# 1
# NO
