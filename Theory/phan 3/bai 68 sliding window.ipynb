# %%
from math import *

if __name__ == '__main__' :
    n, k = map(int, input().split())
    a = list(map(int, input().split()))
    s = sum(a[:k])
    print(s, end = ' ')
    for i in range(1, n - k + 1) :
        s = s - a[i - 1] + a[i + k - 1]
        print(s, end = ' ')
# Out:
# 5 2
# 1 2 3 4 5
# 3 5 7 9
