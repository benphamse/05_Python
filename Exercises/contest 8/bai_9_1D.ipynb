# %%
n = int(input())
a = list(map(int, input().split()))
d = {}
for x in a : 
    if x in d :  d[x] += 1
    else :  d[x] = 1
a.sort()
e = d.copy()
for x in a : 
    if(e[x] != 0) : 
        print(x, e[x])
        e[x] = 0
print()
for val, fre in d.items() : 
    print(val, fre)
