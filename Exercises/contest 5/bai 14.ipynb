# %%
def gcd(a, b) :
    while b :
        a, b = b, a % b
    return a

if __name__ == '__main__' :
    n = int(input())
    a = list(map(int, input().split()))
    res = a[0]
    for i in range(1, n) :
        res = gcd(a[i], res)
    print(res)
