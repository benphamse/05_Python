# %%
# to hop 

from math import *

def tohop(n, k) :
    return factorial(n) // (factorial(k) * factorial(n - k))

if __name__ == '__main__' :
    print(comb(10, 2), tohop(10, 2))

# nC2 = (n - 1) * n // 2
# Out:
# 45 45
