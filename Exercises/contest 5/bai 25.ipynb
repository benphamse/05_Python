# %%
from sys import stdin

even , odd = 0, 0
a = []
for s in stdin :
    a = map(int, s.split())
    for i in a :
        if i % 2 == 0 :
            even += 1
        else : 
            odd += 1

            
if even > odd : print("CHAN")
elif even < odd : print("LE")
else : print("CHANLE")
# Out:
# CHANLE
