# %%
from math import *

def primeK(n, k) :
    for i in range(2, isqrt(n) + 1) :
        if n % i == 0 :
            while n % i == 0 :
                k -= 1
                if k == 0 : 
                    return i
                elif k < 0 : 
                    return -1
                n //= i
    if n != 1 and k == 1 : return n
    return -1
if __name__ == '__main__' :
    n, k = map(int, input().split())
    print(primeK(n, k))
# Out:
# 28 3
# 7
