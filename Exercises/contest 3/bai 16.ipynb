# %%
from math import *

def sumDig(n) :
    sum = 0
    while n :
        sum += n % 10
        n //= 10
    return sum

def smith(n) :
    sum = 0
    ans = sumDig(n)
    for i in range(2, isqrt(n) + 1) :
        if n % i == 0 :
            while (n % i == 0) : 
                sum += sumDig(i)
                n //= i
    if sum == 0 :
        return 0
    if n != 1 : 
        sum += sumDig(n)
    return sum == ans

if __name__ == '__main__' :
    n = int(input())
    print("YES" if smith(n) else "NO")
# Out:
# 666
# True
