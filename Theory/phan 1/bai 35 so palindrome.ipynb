# %%
def palindrome (n) :
    tmp = n
    rev = 0
    while n != 0 :
        rev = rev * 10 + n % 10
        n //= 10
    return rev == tmp

if __name__ == '__main__' :
    n = int(input())
    print(palindrome(n))
# Out:
# 121
# True
