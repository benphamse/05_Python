# %%
from math import *

def prime(n) :
    if n < 2 : return False
    for i in range(2, isqrt(n) + 1) :
        if n % i == 0 : return False
    return True

if __name__ == '__main__' :
    n = int(input())
    a = list(map(int, input().split()))
    sum = 0
    cnt = 0
    for x in a :
        if prime(x) :
            cnt += 1
            sum += x
    print('%.3f' % (sum / cnt))
# Out:
# 5
# -911 234 151 347 231
# 249.000
