# %%
fac = [0] * (10 ** 6  + 1)
mod = (10 ** 9 + 7)
def init() :
    fac[0] = 1
    for i in range(1, 10 ** 6 + 1) :
        fac[i] = fac[i - 1] * i
        fac[i] %= mod
init()
n = int(input())
for i in range(n) :
    k = int(input())
    print(fac[k])
# Out:
# 4
# 5
# 120
# 11
# 39916800
# 10
# 3628800
# 13
# 227020758
