# %%
import os

f = open('input.txt', 'r')
f1 = open('output.txt', 'w')
# print(f.read())
for line in f : 
#     print(line)
    f1.write(line)
f.close()
f1.close()
if os.path.exists('output.txt') : 
    print('FOUND')
#     os.remove("output.txt")
else : 
    print('NOT FOUND')
# Out:
# FOUND
