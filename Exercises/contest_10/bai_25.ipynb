# %%
def minNumber(m, s) :
    if (m * 9 < s) : 
        return False
    ans = "";
    s -= 1
    while(m > 1) :
        if (s >= 10) :
            ans = "9" + ans
            s -= 9
        else :
            ans = str(s) + ans
            s = 0
        m -= 1
    ans = str(s + 1) + ans
    return ans

def maxNumber(m, s) : 
    if (m * 9 < s) : 
        return False
    ans = ""
    while(m) :
        if s >= 10 :
            ans += "9"
            s -= 9
        else : 
            ans += str(s)
            s = 0
        m -= 1
    return ans
        
if __name__ == '__main__' : 
    m, s = map(int, input().split())
    if maxNumber(m, s) == False : 
        print("NOT FOUND")
    else : 
        print(minNumber(m, s))
        print(maxNumber(m, s))
