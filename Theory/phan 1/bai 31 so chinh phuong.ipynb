# %%
# square number

from math import *

def square (n) :
    can = isqrt(n)
    return can * can == n
def cube (n) :
    can = int(pow(n, 1 / 3) + 0.5) # nguy hiem 
    print(can)
    return can ** 3 == n

if __name__ == '__main__' :
    n = int(input())
    if (cube(n)) : print ("OKE")
    else : print ("NO")
# Out:
# 1000
# 10
# OKE
