# %%
Tribo = [0] * (10 ** 6 + 1)
mod = (10 ** 9 + 7)

def init() :
    global Tribonacci
    Tribo[0], Tribo[1], Tribo[2] = 0, 0, 1
    for i in range(3, 10 ** 6 + 1) :
        Tribo[i]  = Tribo[i - 1] + Tribo[i - 2] + Tribo[i - 3]
        Tribo[i] %= mod

init()
n = int(input())
for i in range(n) :
    k = int(input())
    print(Tribo[k])
# Out:
# 1
# 3
# 1
