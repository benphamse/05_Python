# %%
n = int(input())
a = list(map(int, input().split()))

def solve(t) :
    if(t == n) :
        return
    print(a[t], end = ' ')
    solve(t + 1)
def solve1(t) :
    if (t == n) :
        return
    solve1(t + 1)
    print(a[t], end = ' ')

solve(0)
print()
solve1(0)
# Out:
# 5
# 1 2 3 4 4
# 1 2 3 4 4
# 4 4 3 2 1
