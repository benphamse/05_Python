# %%
def convertHex(n) :
    if n == 0 :
        return
    convertHex(n // 16)
    r = n % 16
    if r <= 9 : 
        print(r, end = '')
    else :
        print(chr(r - 10 + ord('A')), end = '')

if __name__ == '__main__' :
    n = int(input())
    if n == 0 : 
        print(0)
    else :
        convertHex(n)
# Out:
# 995
# 3E3
