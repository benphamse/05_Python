# %%
fb = [0] * 95
def fibo() :
    global fibo
    fb[0] = 0
    fb[1] = 1
    for i in range(2, 93) :
        fb[i] = fb[i - 1] + fb[i - 2]

if __name__ == '__main__' :
    fibo();
    n = int(input())
    a = list(map(int, input().split()))
    ok = True
    for i in a :
        if(i in fb) :
            print(i, end = ' ')
            ok = False
    if(ok) : print("NONE")
# Out:
#   Cell In[1], line 2
#     def fibo(){}
#               ^
# SyntaxError: expected ':'
