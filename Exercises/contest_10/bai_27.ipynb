# %%
if __name__ == '__main__' :
    s = input()
    ans, cnt = s[0], 1
    t, tmp = s[0], 1
    for i in range(1, len(s)) :
        if (s[i] != s[i - 1]) :
            t += s[i]
            tmp += 1
            if (tmp > cnt) :
                cnt = tmp
                ans = t
            elif(tmp == cnt) :
                if (ans < t) :
                    ans = t
        else :
            t = s[i]
            tmp = 1
    print(ans)
