# %%
s = input()
s = ' '.join((s.title()).split())
t = input()
if (t[2]) != ('/') :
    t = '0' + t
z = ''
if t[5] != '/' :
    t = t[0:3] + '0' + t[3::]
print(s)
print(t)
# Out:
# pham duy chien
# 1/5/2003
# 01/5/2003
# Pham Duy Chien
# 01/05/2003
