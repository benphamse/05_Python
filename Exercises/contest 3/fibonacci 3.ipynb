# %%
def fibo(n) :
    fn1, fn2 = 1, 1
    for i in range(2, 93) :
        fn = fn1 + fn2
        if fn >= n : return fn
        fn1, fn2 = fn, fn1
if __name__ == '__main__' :
    n = int(input())
    print(fibo(n))
# Out:
# 12
# 13
