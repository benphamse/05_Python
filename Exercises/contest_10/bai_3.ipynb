# %%
s = input()
cnt = [0] * 256
for x in s : 
    cnt[ord(x)] += 1
for x in range(256) : 
    if(cnt[x] != 0) : 
        print(chr(x), cnt[x])
print()
for x in s : 
    if cnt[ord(x)] != 0 : 
        print(x, cnt[ord(x)])
        cnt[ord(x)] = 0
# Out:
#   Cell In[1], line 6
#     if(cnt[x] != 0) :
#                       ^
# SyntaxError: incomplete input
