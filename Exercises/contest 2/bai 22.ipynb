# %%
n = int(input())

for i in range(n) :
    for j in range(n) :
        if j <= i :
            print('*', end = '')
        else :
            print(' ', end = '')
    print('')  
print('')

for i in range(1, n + 1) :
    for j in range(1, n + 1) :
        if j <= n - i + 1 :
            print('*', end = '')
        else :
            print('', end = '')
    print('')
print('')

for i in range(1, n + 1) :
    for j in range(1, n + 1) :
        if j >= n - i + 1 :
            print('*', end = '')
        else :
            print(' ', end = '')
    print('')
print('')

for i in range(1, n + 1) :
    for j in range(1, n + 1) :
        if j >= i : 
            print('*', end = '')
        else :
            print(' ', end = '')
    print('')
print('')

for i in range(1, n + 1) :
    for j in range(1, n + 1) :
        if i == n :
            print('*', end = '')
        elif j == 1 or j == i :
            print('*', end = '')
        else :
            print(' ', end = '')
    print('')
# Out:
# 5
# *
# **
# ***
# ****
# *****
#
# *****
# ****
# ***
# **
# *
#
#     *
#    **
#   ***
#  ****
# *****
#
# *****
#  ****
#   ***
#    **
#     *
#
# *
# **
# * *
# *  *
# *****
