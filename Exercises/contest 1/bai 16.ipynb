# %%
# A -> Z : 65 -> 90
# a -> z : 97 -> 127
# 0 - 9 : 48 -> 57

# print(ord('A'))
# print(chr(65))

res = input()
if(res == 'z' or res == 'Z') : print ('a')
else : 
    tmp = ord(res)
    tmp += 1
    print (chr(tmp).lower())
# Out:
# a
# b
