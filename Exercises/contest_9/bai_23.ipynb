# %%
n = int(input())
a = []
for i in range(n) : 
    b = list(map(int, input().split()))
    a.append(b)
for i in range(n) : 
    for j in range(n) : 
        if i == 0 : 
            print(a[i][j], end = ' ')
        elif i == n - 1 : 
            print(a[i][j], end = ' ')
        else : 
            if j == 0 or j == n - 1 : 
                print(a[i][j], end = ' ')
            else : 
                print(end = '')
# Out:
#   Cell In[1], line 7
#     for j in range(n) :
#                         ^
# SyntaxError: incomplete input
