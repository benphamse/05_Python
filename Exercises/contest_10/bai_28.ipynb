# %%
if __name__ == '__main__' :
    s = input()
    s += '#'
    ans, tmp = 0, 0
    for i in range(len(s)) :
        if(s[i].isdigit()) :
            tmp = tmp * 10 + (ord(s[i]) - ord('0'))
        else :
            ans = max(tmp, ans)
            tmp = 0
    print(ans)
