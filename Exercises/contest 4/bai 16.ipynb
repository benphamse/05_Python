# %%
def maxDig(n) :
    if n <= 9 : return n
    return max(n % 10, maxDig(n // 10))
def minDig(n) :
    if n <= 9 : return n
    return min(n % 10, minDig(n // 10))

if __name__ == '__main__' :
    n = int(input())
    print(maxDig(n), minDig(n))
# Out:
# 123
# 3 1
