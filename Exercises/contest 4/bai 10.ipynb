# %%
def sum(n) :
    if n == 1 : return 1
    return 1 / n + sum(n - 1)

if __name__ == '__main__' :
    n = int(input())
    print('{:.3f}'. format(sum(n)))
#     print('%.3f' % sum(n))
# Out:
# 18
# 3.495
# 3.495
