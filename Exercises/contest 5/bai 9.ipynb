# %%
n = int(input())
a = list(map(int, input().split()))
cnt = [0] * 10 ** 4
for i in a :
    cnt[i] += 1
for i in a:
    if(cnt[i] != 0) :
        print(i, cnt[i])
        cnt[i] = 0
# Out:
# 7
# 4 2 6 3 0 7 7
# 4 1
# 2 1
# 6 1
# 3 1
# 0 1
# 7 2
