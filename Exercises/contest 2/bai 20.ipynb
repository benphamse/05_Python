# %%
n = int(input())
if n % 2 == 0 : 
    print(n // 2)
    for i in range(n // 2) : 
        print(2, end = ' ')
elif n >= 3 :
    print(1 + (n - 3) // 2)
    for _ in range((n - 3) // 2) :
        print(2, end = ' ')
    print(3, end = ' ') 
else : 
    print(-1)
# Out:
# 5
# 2
# 2
# 3
