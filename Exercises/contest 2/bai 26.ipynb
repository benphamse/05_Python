# %%
a, b, n = map(int, input().split())

ok = True
for i in range(n + 1) :
    for j in range(n + 1) :
        if(i * a + b * j == n) :
            print("YES")
            ok = False
            break
    if (ok == False) :
        break
if(ok == True) : 
    print("NO")
# Out:
# 5 8 28
# YES
