# %%
n, m = map(int, input().split())
a = set(map(int, input().split()))
b = set(map(int, input().split()))
d = dict({})
se = set({})
for x in a : 
    d[x] = 1
    se.add(x)
for x in b : 
    se.add(x)
    if x in d : 
        d[x] = 2
    else : 
        d[x] = 1
tmp = []
for x in d : 
    if(d[x] == 2) : 
        tmp.append(x)
tmp.sort()
for x in tmp : 
    print(x, end = ' ')
print()
tmp = list(se)
tmp.sort()
for x in tmp : 
    print(x, end = ' ')
