# %%
n, x = map(int, input().split())
a = list(map(int, input().split()))
a.sort()
ans, l, r = 0, 0, n - 1
while(l <= r) : 
    if(a[l] + a[r] <= x) : 
        ans += 1
        l += 1
        r -= 1
    else : 
        ans += 1
        r -= 1
print(ans)
# Out:
#   Cell In[2], line 8
#     while(i < n){}
#                 ^
# SyntaxError: invalid syntax
