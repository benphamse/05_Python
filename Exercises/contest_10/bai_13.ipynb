# %%
a = list(map(str, input().split()))
d = dict({})
for x in a : 
    if x not in d : d[x] = 1
    else : d[x] += 1
for x in sorted(d) : 
    print(x, d[x])
print()
for x in a : 
    if d[x] != 0 : 
        print(x, d[x])
        d[x] = 0
