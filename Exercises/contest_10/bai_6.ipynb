# %%
s1 = input()
s2 = input()
cnt = [0] * 256
cnt1 = [0] * 256
for x in s1 : 
    cnt[ord(x)] = 1
for x in s2 : 
    cnt1[ord(x)] = 1
for x in range(256) : 
    if(cnt[x] == 1 and cnt1[x] == 0) : 
        print(chr(x), end = '')
print()
for x in range(256) : 
    if(cnt[x] == 0 and cnt1[x] == 1) : 
        print(chr(x), end = '')
