# %%
from math import *

def sphenic(n) :
    cnt = 0
    i = 2
    while i <= isqrt(n) : 
        if n % i == 0 : 
            mu = 0
            while n % i == 0 :
                mu += 1
                n //= i
            if mu >= 2 : return 0
            cnt += 1
    if cnt == 3 : return 1
    return 0
if __name__ == '__main__' :
    n = int(input())
    print(sphenic(n))
# Out:
# 30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 17
#      15 if __name__ == '__main__' :
#      16     n = int(input())
# ---> 17     print(sphenic(n))
#
# Cell In[8], line 5, in sphenic(n)
#       3 def sphenic(n) :
#       4     cnt = 0
# ----> 5     while i <= isqrt(n) :
#       6         if n % i == 0 :
#       7             mu = 0
#
# NameError: name 'i' is not defined
