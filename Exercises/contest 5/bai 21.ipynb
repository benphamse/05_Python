# %%
n = int(input())
a = list(map(int, input().split()))
b = [0] * 10 ** 5

for i in a :
    b[i] += 1
c = b[:]
for i in a:
    if(b[i] != 0):
        print(i, b[i])
        b[i] = 0
print('')
b = c[::]
minval, maxval = 10 ** 7, -10 ** 7
idx, idx1 = 0, 0
for i in range(min(a), max(a) + 1) :
    if(c[i] != 0) :
        print(i, c[i])
        if(c[i] >= maxval) :
            maxval = c[i]
            idx1 = i
        if (c[i] < minval) :
            minval = c[i]
            idx = i
        c[i] = 0
print('')
print(idx1, idx, sep = '\n')
