# %%
n = int(input())
a = list(map(int, input().split()))
max1, max2 = -10 ** 7, -10 ** 7

for i in range(n) :
    if a[i] > max1 :
        max1, max2 = a[i], max1
    elif a[i] > max2 :
        max2 = a[i]
print(max1, max2)
