# %%
if __name__ == "__main__" : 
    s = input()
    s += "#"
    ans, tmp = s[0], 1
    t, cnt = s[0], 1
    for i in range(1, len(s)) :
        if (s[i] == s[i - 1]) : 
            t += s[i]
            cnt  += 1
        else :
            if (tmp < cnt) :
                tmp = cnt
                ans = t
            elif (tmp == cnt) :
                if ans < t :
                    ans = t
            t = s[i]
            cnt = 1
    print(ans)
# Out:
#   Cell In[1], line 6
#     if (s[i] == s[i + 1]){}
#                          ^
# SyntaxError: invalid syntax
