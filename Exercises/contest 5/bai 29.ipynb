# %%
n = int(input())
a = list(map(int, input().split()))

b = [0] * 10 ** 7
maxval, idx = -10 ** 9, -1
for i in a :
    b[i] += 1
    if(b[i] > maxval) :
        maxval = b[i]
        idx = i
    elif(b[i] == maxval and i < idx) :
        idx = i
print(idx, maxval)
