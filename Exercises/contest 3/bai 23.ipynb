# %%
from math import *

if __name__ == '__main__' :
    n = int(input())
    sum = 1
    for i in range (2, isqrt(n) + 1) :
        if n % i == 0 :
            sum += i
            if n // i != i :
                sum += n // i
    sum += n
    print(sum)
# Out:
# 100
# 217
