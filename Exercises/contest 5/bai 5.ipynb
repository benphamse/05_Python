# %%
n = int(input())
a = list(map(int, input().split()))
b = [a[i] for i in range(n) if a[i] % 2 == 0 and i % 2 == 0]

if b == [] :
    print("NONE")
else :
    for i in b :
        print(i, end = ' ')
# Out:
# 5
# 1 3 5 7 9
# NONE
