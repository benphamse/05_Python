# %%
s = input()
a = list(map(str, (s.title()).split()))
t = ' '.join(a[0:len(a) - 1:])
print(f'{t}, {a[len(a) - 1].upper()}')
print(f'{a[len(a) - 1].upper()}, {t}')
# Out:
# pham duy chien
# Pham Duy , CHIEN
# CHIEN , Pham Duy
