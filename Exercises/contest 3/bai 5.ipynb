# %%
from math import *

def prime(n) :
    for i in range(2, isqrt(n) + 1) :
        if n % i == 0 :
            return False
    return n > 1

if __name__ == '__main__' :
    t = int(input())
    while t :
        n = int(input())
        for i in range(2, n // 2 + 1) :
            if prime(i) and prime(n - i) :
                print (i, n - i)
        t -= 1
# Out:
# 2
# 6
# 3 3
# 10
# 3 7
# 5 5
