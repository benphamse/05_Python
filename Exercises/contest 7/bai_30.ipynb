# %%
n, l = map(int, input().split())
a = list(map(int, input().split()))

a.sort()
ans = max(a[0] - 0, l - a[n - 1])
for i in range(n - 1) :
    tmp = (a[i + 1] - a[i]) / 2
    if(tmp > ans) :
        ans = tmp

print('{:.10f}'. format(ans))
# Out:
# 7 15
# 15 5 3 7 9 14 0
# 5.0000000000
