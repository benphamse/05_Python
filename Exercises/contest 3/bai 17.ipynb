# %%
from math import *

def prime(n) :
    mx = 1
    for i in range(2, isqrt(n) + 1) : 
        if n % i == 0 :
            mx = i
            while (n % i == 0) :
                n //= i
    if (n != 1) : 
        mx = n
    return mx

if __name__ == '__main__' :
    n = int(input())
    while n:
        k = int(input())
        print(prime(k))
        n -= 1
# Out:
# 2
# 2
# 2
# 5
# 5
