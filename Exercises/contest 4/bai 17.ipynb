# %%
def oke(n):
    if n <= 9 : 
        print(n)
        return
    print(n % 10, end = ' ')
    oke(n // 10)
def rin(n) :
    if n <= 9: 
        print(n, end = ' ')
        return
    rin(n // 10)
    print(n % 10, end = ' ')
    
if __name__ == '__main__' :
    n = int(input())
    rin(n)
    print("")
    oke(n)
# Out:
# 123
# 3 2 1
#
# 1 2 3
