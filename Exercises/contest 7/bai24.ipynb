# %%
n, k = map(int, input().split())
a = list(map(int, input().split()))
a[1:] = sorted(a[1:], reverse = True)
sum = a[0]
for i in range(1, n) :
    if(i <= k) :
        sum += a[i]
    else : 
        sum -= a[i]
print(sum)
# Out:
# 5 2
# 28 9 5 1 69
# 100
