# %%
n = int(input())
a = list(map(int, input().split()))

c = [0] * 10 ** 7

for i in range(n) :
    c[a[i]] += 1
    
for i in range(min(a), max(a) + 1) :
    if(c[i] != 0) : 
        print(i, c[i])
        c[i] = 0
