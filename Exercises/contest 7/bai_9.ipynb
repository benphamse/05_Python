# %%
n = int(input())
a = list(map(int, input().split()))

def binarySearch(x) : 
    l, r = 0, n - 1
    while l <= r : 
        m = (l + r) // 2
        if(a[m] == x) :
            return True
        elif(a[m] > x) :
            l = m + 1
        else : 
            r = m - 1
    return False

if __name__ == '__main__' :
    k = int(input())
    for i in range(k) :
        t = int(input())
        print("YES" if binarySearch(t) else "NO")
# Out:
# 3
# 1 2 3
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 18
#      16 if __name__ == '__main__' :
#      17     k = int(input())
# ---> 18     for i in k :
#      19         t = int(input())
#      20         print("YES" if binarySearch(t) else "NO")
#
# TypeError: 'int' object is not iterable
