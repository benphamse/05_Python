# %%
if __name__== "__main__" :
    n = 0
    do 
        n = int(input("nhap so > 0"))
    while(n <= 0)
# Out:
#   Cell In[10], line 4
#     n = int(input("nhap so > 0"))
#     ^
# IndentationError: unexpected indent
