# %%
n = int(input())
a = [[0 for _ in range(n)] for _ in range(n)]
for i in range(n) : 
    a[i] = list(map(int, input().split()))
c = []
for i in range(n) : 
    b = [row[i] for row in a] 
    b.sort()
    c.append(b)
for i in range(n) : 
    for j in range(n) : 
        print(c[j][i], end = ' ')
    print()
# Out:
# 2
# 1 2
# 1 2
# [[1, 1], [2, 2]]
