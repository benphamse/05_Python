# %%
n = int(input())
a = list(map(int, input().split()))

b = [0] * 10 ** 7
val, idx = -1, -1e9
for i in a :
    b[i] += 1
    
for i in a :
    if(b[i] > idx) :
        idx = b[i]
        val = i
print(val, idx)
