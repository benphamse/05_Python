# %%
def sumEven(n) :
    if n <= 9 : 
        if n % 2 == 0 : return n
        else : return 0
    else : 
        r = n % 10
        if r % 2 == 0 : 
            return r + sumEven(n // 10)
        else : 
            return sumEven(n // 10)
    
def sumOdd(n) : 
    if n <= 9: 
        if n % 2 == 1 : return n
        else : return 0
    else : 
        r = n % 10
        if r % 2 == 1 :
            return r + sumOdd(n // 10)
        else :
            return sumOdd(n // 10)
    
if __name__ == '__main__' :
    n = int(input())
    print(sumEven(n), sumOdd(n), sep = '\n')
# Out:
# 0
# 0
# 0
