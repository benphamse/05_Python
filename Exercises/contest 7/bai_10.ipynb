# %%
n, x = map(int, input().split())
a = list(map(int, input().split()))

def binarySearch(k) :
    l, r = 0, n - 1
    res = -1
    while l <= r : 
        m = (l + r) // 2
        if(a[m] == k) : 
            res = m
            r = m - 1
        elif(a[m] > k) :
            r = m - 1
        else :
            l = m + 1
    return res

def binarySearch1(k) :
    l, r = 0, n - 1
    res = -1
    while l <= r : 
        m = (l + r) // 2
        if(a[m] == k) : 
            res = m
            l = m + 1
        elif(a[m] > k) :
            r = m - 1
        else :
            l = m + 1
    return res

def binarySearch2(k) :
    l, r = 0, n - 1
    res = -1
    while l <= r : 
        m = (l + r) // 2
        if(a[m] >= k) : 
            res = m
            r = m - 1
        else :
            l = m + 1
    return res

def binarySearch3(k) :
    l, r = 0, n - 1
    res = -1
    while l <= r : 
        m = (l + r) // 2
        if(a[m] > k) : 
            res = m
            r = m - 1
        else :
            l = m + 1
    return res


if __name__ == '__main__' :
    z, z1 = binarySearch(x), binarySearch1(x)
    if(z == -1) :
        print(z, z1, binarySearch2(x), binarySearch3(x), 0, 
             sep = '\n')
    else :
        print(z, z1, binarySearch2(x), binarySearch3(x), z1 - z + 1, 
             sep = '\n')
# Out:
#   Cell In[2], line 61
#     print(binarySearch(x), binarySearch1(x), binarySearch2(x), binarySearch3(x), binarySearch4(x)
#                                                                                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
