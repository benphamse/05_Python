# %%
n = int(input())
a = list(map(int, input().split()))
q = int(input())
for i in range(q) :
    x, y = map(int, input().split())
    if x == 1 :
        a.append(y)
    elif x == 2 :
        if y in a : 
            a.remove(y)
    else :
        if y in a : 
            print("YES")
        else : 
            print('NO')
# Out:
#   Cell In[1], line 11
#     else :
#           ^
# SyntaxError: incomplete input
