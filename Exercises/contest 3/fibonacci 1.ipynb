# %%
n = int(input())

fn1, fn2 = 1, 1
if n == 1 : 
    print (fn1)
else:
    print(fn1, fn2, sep = '\n')
for i in range(2, n) :
    fn = fn1 + fn2
    print(fn)
    fn2, fn1 = fn1, fn
# Out:
# 1
# 1
# 1
