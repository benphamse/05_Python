# %%
def gcd(a, b) :
    while b :
        a, b = b, a % b
    return a

def lcm(a, b) :
    return a * b // gcd(a, b)

def numDig(n) :
    cnt = 0
    while n :
        cnt += 1
        n //= 10
    return cnt

if __name__ == '__main__' :
    x, y, z, n = map(int, input().split())
    k = lcm(lcm(x, y), z)
    d = numDig(k)
    if d > n : print(-1)
    else :
        print((10 ** (n - 1) // k + 1) * k)
# Out:
# 2 3 5 4
# 30
# 1020
