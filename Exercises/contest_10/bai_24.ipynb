# %%
s = input()
def check() : 
    cnt = 0
    d = dict({})
    for r in range(len(s)) : 
        cnt += 1
        if s[r] not in d : 
            d[s[r]] = 1
        else : 
            d[s[r]] += 1
    for x in d : 
        if d[x] != 0: 
            cnt += (d[x] - 1) * d[x] // 2
    return cnt
if __name__ == '__main__' : 
    print(check())
