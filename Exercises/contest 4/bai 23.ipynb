# %%
n = int(input())
a = list(map(int, input().split()))

def check(t) :
    if (t == n) :
        return True
    if(a[t] % 2 == 1) :
        return False
    return check(t + 1)

print("YES" if check(0) else "NO")
