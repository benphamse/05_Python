# %%
n = int(input())
a = [[0 for _ in range(n)] for _ in range(n)]
for i in range(n) : 
    a[i] = list(map(int, input().split()))
    a[i].sort()
for i in range(n) : 
    for j in range(n) : 
        print(a[i][j], end = ' ')
    print()
