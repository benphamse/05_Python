# %%
n = 500 # global

def local_scope() :
    global n
    n = 10
    print(n)

if __name__ == '__main__' :
    if True :
        x = 100
        print(x)
    print(x)
#     trong if, else , while , for khai bao van su dung dc ben ngoai
# Out:
# 100
# 100
