# %%
INF = 1e18
def solve(n) :
    if n == 1 : 
        return 0
    cnt1, cnt2, cnt3 = INF, INF, INF
    if n % 2 == 0 :
        cnt1 = 0
        cnt1 += solve(n // 2)
    if n % 3 == 0 :
        cnt2 = 0
        cnt2 += solve(n // 3)
    if n > 1 :
        cnt3 = 0
        cnt3 += solve(n - 1)
    return 1 + min({cnt1, cnt2, cnt3})

if __name__ == '__main__' :
    n = int(input())
    print(solve(n))
# Out:
# 38
# 5
