# %%
n, x = map(int, input().split())
a = list(map(int, input().split()))

if(x not in a) : 
    print("NOT FOUND")
else :
    a.remove(x)
    for i in a : 
        print(i, end = ' ')
# Out:
#   Cell In[1], line 6
#     else :
#           ^
# SyntaxError: incomplete input
