# %%
def convertbi(n):
    if n == 0 : 
        return 0
    convertbi(n // 2)
    print(n % 2, end = '')

if __name__ == '__main__' :
    n = int(input())
    if n == 0 : 
        print(0)
    else :
        convertbi(n)
# Out:
# 0
# 0
